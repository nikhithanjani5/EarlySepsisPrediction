# %% [markdown]
# # Preprocessing Pipeline (Leakage-Safe)
# ## Early Sepsis Prediction
#
# ### Objectives
# - Load the raw dataset in a reproducible manner
# - Create a leakage-safe patient-level Train/Validation/Test split (stratified by patient-level sepsis)
# - Save split patient IDs for consistent downstream experiments
# - Prepare the data representation required for baseline ML models

# %%
from pathlib import Path
import numpy as np
import pandas as pd

from sklearn.model_selection import train_test_split

# %% [markdown]
# Load Data

# %%
# Paths
DATA_DIR = Path("../data/raw")
DATA_FILE = DATA_DIR / "Dataset.csv"

INTERIM_DIR = Path("../data/interim")
INTERIM_DIR.mkdir(parents=True, exist_ok=True)

# Load dataset
df = pd.read_csv(DATA_FILE)

print("Loaded Dataset.csv")
print("Shape:", df.shape)
print("Columns:", len(df.columns))
# Out:
# Loaded Dataset.csv
# Shape: (1552210, 44)
# Columns: 44

# %% [markdown]
# Defining Key Columns

# %%
patient_id_col = "Patient_ID"
time_col = "ICULOS"
target_col = "SepsisLabel"

# Drop obvious index artifact if present
if "Unnamed: 0" in df.columns:
    df = df.drop(columns=["Unnamed: 0"])

print("After dropping index artifact (if present):", df.shape)
print("Unique patients:", df[patient_id_col].nunique())
# Out:
# After dropping index artifact (if present): (1552210, 43)
# Unique patients: 40336

# %%
RANDOM_SEED = 42

# Patient-level label: 1 if patient ever becomes septic, else 0
patient_labels = (
    df.groupby(patient_id_col)[target_col]
      .max()
      .astype(int)
)

print("Patients:", patient_labels.shape[0])
print("Sepsis patients:", int(patient_labels.sum()))
print("Patient-level prevalence:", round(patient_labels.mean(), 4))
# Out:
# Patients: 40336
# Sepsis patients: 2932
# Patient-level prevalence: 0.0727

# %% [markdown]
# Leakage Safe Split

# %%
# 70% train, 30% temp
train_ids, temp_ids = train_test_split(
    patient_labels.index,
    test_size=0.30,
    random_state=RANDOM_SEED,
    stratify=patient_labels.values
)

# temp -> 15% val, 15% test
val_ids, test_ids = train_test_split(
    temp_ids,
    test_size=0.50,
    random_state=RANDOM_SEED,
    stratify=patient_labels.loc[temp_ids].values
)

print("Train patients:", len(train_ids))
print("Val patients:  ", len(val_ids))
print("Test patients: ", len(test_ids))

def prevalence(ids):
    return patient_labels.loc[ids].mean()

print("\nPatient-level sepsis prevalence:")
print("Train:", round(prevalence(train_ids), 4))
print("Val:  ", round(prevalence(val_ids), 4))
print("Test: ", round(prevalence(test_ids), 4))

# Sanity: no overlap
overlap = (set(train_ids) & set(val_ids)) | (set(train_ids) & set(test_ids)) | (set(val_ids) & set(test_ids))
print("\nPatient overlap across splits:", len(overlap))# 70% train, 30% temp
train_ids, temp_ids = train_test_split(
    patient_labels.index,
    test_size=0.30,
    random_state=RANDOM_SEED,
    stratify=patient_labels.values
)

# temp -> 15% val, 15% test
val_ids, test_ids = train_test_split(
    temp_ids,
    test_size=0.50,
    random_state=RANDOM_SEED,
    stratify=patient_labels.loc[temp_ids].values
)

print("Train patients:", len(train_ids))
print("Val patients:  ", len(val_ids))
print("Test patients: ", len(test_ids))

def prevalence(ids):
    return patient_labels.loc[ids].mean()

print("\nPatient-level sepsis prevalence:")
print("Train:", round(prevalence(train_ids), 4))
print("Val:  ", round(prevalence(val_ids), 4))
print("Test: ", round(prevalence(test_ids), 4))

# Sanity: no overlap
overlap = (set(train_ids) & set(val_ids)) | (set(train_ids) & set(test_ids)) | (set(val_ids) & set(test_ids))
print("\nPatient overlap across splits:", len(overlap))
# Out:
# Train patients: 28235
# Val patients:   6050
# Test patients:  6051
#
# Patient-level sepsis prevalence:
# Train: 0.0727
# Val:   0.0727
# Test:  0.0727
#
# Patient overlap across splits: 0
# Train patients: 28235
# Val patients:   6050
# Test patients:  6051
#
# Patient-level sepsis prevalence:
# Train: 0.0727
# Val:   0.0727
# Test:  0.0727
#
# Patient overlap across splits: 0

# %%
pd.Series(train_ids).to_csv(INTERIM_DIR / "train_patient_ids.csv", index=False, header=[patient_id_col])
pd.Series(val_ids).to_csv(INTERIM_DIR / "val_patient_ids.csv", index=False, header=[patient_id_col])
pd.Series(test_ids).to_csv(INTERIM_DIR / "test_patient_ids.csv", index=False, header=[patient_id_col])

print("Saved split IDs to:", INTERIM_DIR.resolve())
# Out:
# Saved split IDs to: C:\Users\Nikhitha\OneDrive\Documents\EarlySepsisPrediction\data\interim

# %% [markdown]
# Build split dataframes + sort by time

# %%
# Build row-level datasets using patient IDs
train_df = df[df[patient_id_col].isin(train_ids)].copy()
val_df   = df[df[patient_id_col].isin(val_ids)].copy()
test_df  = df[df[patient_id_col].isin(test_ids)].copy()

print("Train rows/cols:", train_df.shape)
print("Val rows/cols:  ", val_df.shape)
print("Test rows/cols: ", test_df.shape)

# Sanity check: no patient overlap between row-level datasets
train_patients = set(train_df[patient_id_col].unique())
val_patients   = set(val_df[patient_id_col].unique())
test_patients  = set(test_df[patient_id_col].unique())

overlap = (train_patients & val_patients) | (train_patients & test_patients) | (val_patients & test_patients)
print("Patient overlap across row-level splits:", len(overlap))
# Out:
# Train rows/cols: (1086436, 43)
# Val rows/cols:   (231472, 43)
# Test rows/cols:  (234302, 43)
# Patient overlap across row-level splits: 0

# %% [markdown]
# Sort each split by patient and ICU time

# %%
# Sort for time-series operations
train_df = train_df.sort_values([patient_id_col, time_col]).reset_index(drop=True)
val_df   = val_df.sort_values([patient_id_col, time_col]).reset_index(drop=True)
test_df  = test_df.sort_values([patient_id_col, time_col]).reset_index(drop=True)

print("Sorted train/val/test by Patient_ID and ICULOS.")
# Out:
# Sorted train/val/test by Patient_ID and ICULOS.

# %% [markdown]
# Define feature columns list

# %%
# Columns to exclude from features
exclude_cols = {patient_id_col, target_col, "Hour", "ICULOS"}

feature_cols = [c for c in train_df.columns if c not in exclude_cols]

print("Number of feature columns:", len(feature_cols))
print("First 15 feature columns:", feature_cols[:15])
# Out:
# Number of feature columns: 39
# First 15 feature columns: ['HR', 'O2Sat', 'Temp', 'SBP', 'MAP', 'DBP', 'Resp', 'EtCO2', 'BaseExcess', 'HCO3', 'FiO2', 'pH', 'PaCO2', 'SaO2', 'AST']

# %%
# --- Capture original missingness BEFORE any filling ---

orig_missing_train = train_df[feature_cols].isna()
orig_missing_val   = val_df[feature_cols].isna()
orig_missing_test  = test_df[feature_cols].isna()

print("Captured original missingness masks.")
# Out:
# Captured original missingness masks.

# %%
MAX_FFILL_HOURS = 6

train_df[feature_cols] = (
    train_df.groupby(patient_id_col)[feature_cols].ffill(limit=MAX_FFILL_HOURS)
)

val_df[feature_cols] = (
    val_df.groupby(patient_id_col)[feature_cols].ffill(limit=MAX_FFILL_HOURS)
)

test_df[feature_cols] = (
    test_df.groupby(patient_id_col)[feature_cols].ffill(limit=MAX_FFILL_HOURS)
)

print(f"Forward fill completed with limit={MAX_FFILL_HOURS} hours.")
# Out:
# Forward fill completed with limit=6 hours.

# %%
# --- Identify values imputed by forward fill ---

after_ffill_missing_train = train_df[feature_cols].isna()

ffill_imputed_train = orig_missing_train & (~after_ffill_missing_train)

print("Forward-fill imputation mask computed.")
# Out:
# Forward-fill imputation mask computed.

# %% [markdown]
# Create missingness indicators

# %%
# Create missingness indicators BEFORE final imputation
missing_indicator_cols = [f"{c}_missing" for c in feature_cols]

train_missing = train_df[feature_cols].isna().astype(int)
val_missing   = val_df[feature_cols].isna().astype(int)
test_missing  = test_df[feature_cols].isna().astype(int)

train_missing.columns = missing_indicator_cols
val_missing.columns   = missing_indicator_cols
test_missing.columns  = missing_indicator_cols

# Attach to datasets
train_df = pd.concat([train_df, train_missing], axis=1)
val_df   = pd.concat([val_df, val_missing], axis=1)
test_df  = pd.concat([test_df, test_missing], axis=1)

print("Missingness indicators added.")
print("Total columns now (train):", train_df.shape[1])
# Out:
# Missingness indicators added.
# Total columns now (train): 82

# %% [markdown]
# Fit medians on train, apply to all splits

# %%
# Compute medians using TRAIN ONLY
train_medians = train_df[feature_cols].median()

# Fill remaining NaNs (after forward fill) using train medians
train_df[feature_cols] = train_df[feature_cols].fillna(train_medians)
val_df[feature_cols]   = val_df[feature_cols].fillna(train_medians)
test_df[feature_cols]  = test_df[feature_cols].fillna(train_medians)

# Sanity check: any NaNs left in feature columns?
print("Remaining NaNs in TRAIN features:", int(train_df[feature_cols].isna().sum().sum()))
print("Remaining NaNs in VAL features:  ", int(val_df[feature_cols].isna().sum().sum()))
print("Remaining NaNs in TEST features: ", int(test_df[feature_cols].isna().sum().sum()))
# Out:
# Remaining NaNs in TRAIN features: 0
# Remaining NaNs in VAL features:   0
# Remaining NaNs in TEST features:  0

# %%
# --- Identify values imputed by median imputation ---

after_median_missing_train = train_df[feature_cols].isna()

median_imputed_train = after_ffill_missing_train & (~after_median_missing_train)

print("Median imputation mask computed.")
# Out:
# Median imputation mask computed.

# %%
# --- Imputation summary table (per variable) ---

summary = pd.DataFrame({
    "orig_missing": orig_missing_train.sum(),
    "ffill_imputed": ffill_imputed_train.sum(),
    "median_imputed": median_imputed_train.sum()
})

summary["orig_missing_pct"] = summary["orig_missing"] / len(train_df)

summary = summary.sort_values("orig_missing_pct", ascending=False)

summary.head(15)
# Out:
#                   orig_missing  ffill_imputed  median_imputed  \
# Bilirubin_direct       1084339          10623         1073716
# Fibrinogen             1079200          31662         1047538
# TroponinI              1075987          53913         1022074
# Bilirubin_total        1070209          88927          981282
# Alkalinephos           1068950          88218          980732
# AST                    1068769          89158          979611
# Lactate                1057319          93842          963477
# PTT                    1054251         164658          889593
# SaO2                   1048617         110373          938244
# EtCO2                  1045740          12980         1032760
# Phosphate              1042875         233001          809874
# HCO3                   1040892         195930          844962
# Chloride               1037207         207363          829844
# BaseExcess             1027193         144035          883158
# ...

# %%
import matplotlib.pyplot as plt

summary["orig_missing_pct"].head(15).plot(kind="bar", figsize=(12,5))

plt.title("Top Variables by Missingness (Train)")
plt.ylabel("Proportion Missing")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# Patient-level imputation proportion

total_imputed = ffill_imputed_train | median_imputed_train

patient_impute_rate = (
    total_imputed
    .groupby(train_df[patient_id_col])
    .mean()
    .mean(axis=1)
)

patient_impute_rate.describe()
# Out:
# count    28235.000000
# mean         0.721104
# std          0.054776
# min          0.401709
# 25%          0.688205
# 50%          0.716599
# 75%          0.754662
# max          0.923077
# dtype: float64

# %%
plt.figure(figsize=(10,4))
plt.hist(patient_impute_rate, bins=50)
plt.title("Patient-Level Imputation Rate Distribution")
plt.xlabel("Mean proportion imputed per patient")
plt.ylabel("Number of patients")
plt.show()

# %%
plot_df = summary.head(15)[["orig_missing_pct","ffill_imputed","median_imputed"]]

plot_df.plot(kind="bar", figsize=(12,5))
plt.title("Missingness vs Imputation Strategy (Top Variables)")
plt.ylabel("Counts")
plt.xticks(rotation=45)
plt.show()

# %%
from pathlib import Path
import pandas as pd

# Create processed folder
PROCESSED_DIR = Path("../data/processed")
PROCESSED_DIR.mkdir(parents=True, exist_ok=True)

# Final modelling feature list
final_feature_cols = feature_cols + missing_indicator_cols

# Save processed datasets (features + label together)
train_df[final_feature_cols + [target_col]].to_parquet(
    PROCESSED_DIR / "train.parquet", index=False
)

val_df[final_feature_cols + [target_col]].to_parquet(
    PROCESSED_DIR / "val.parquet", index=False
)

test_df[final_feature_cols + [target_col]].to_parquet(
    PROCESSED_DIR / "test.parquet", index=False
)

# Save feature column names separately
pd.Series(final_feature_cols).to_csv(
    PROCESSED_DIR / "feature_cols.csv", index=False, header=["feature"]
)

print("Processed datasets saved successfully.")
print("Saved to:", PROCESSED_DIR.resolve())
# Out:
# Processed datasets saved successfully.
# Saved to: C:\Users\Nikhitha\OneDrive\Documents\EarlySepsisPrediction\data\processed

# %%
from pathlib import Path
import pandas as pd

PROCESSED_DIR = Path("../data/processed")
PROCESSED_DIR.mkdir(parents=True, exist_ok=True)

final_feature_cols = feature_cols + missing_indicator_cols

cols_to_save = ["Patient_ID", "ICULOS", target_col] + final_feature_cols

train_df[cols_to_save].to_parquet(PROCESSED_DIR / "train.parquet", index=False)
val_df[cols_to_save].to_parquet(PROCESSED_DIR / "val.parquet", index=False)
test_df[cols_to_save].to_parquet(PROCESSED_DIR / "test.parquet", index=False)

pd.Series(final_feature_cols).to_csv(
    PROCESSED_DIR / "feature_cols.csv", index=False, header=["feature"]
)

print("Re-saved processed datasets with Patient_ID and ICULOS included.")
# Out:
# Re-saved processed datasets with Patient_ID and ICULOS included.
